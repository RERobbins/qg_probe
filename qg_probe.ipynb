# %% [markdown]
# ### Setup

# %%
from qg_probe import *

import pprint

pd.set_option("display.max_colwidth", None)
# Out:
# 2022-12-22 18:42:15.234323: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### Play Time

# %%
help(Probe)
# Out:
# Help on class Probe in module qg_probe:
#
# class Probe(builtins.object)
#  |  A class used to represent an Awesome Puppies Question Generation Probe
#  |  ...
#  |
#  |  Attributes
#  |  ----------
#  |  models : dict
#  |      a dictionary of cached models
#  |  tokenizers : dict
#  |      a dictionary of cached tokenizers
#  |
#  |  Methods
#  |  -------
#  |  predict(context, answer, base_model='T5', training_dataset='amalgam',
#  |          num_beams=4, early_stopping=True, no_repeat_ngram_size=3,
#  |          maximum_input_length=1024, maximum_target_length=50)
#  |
#  |      returns a prediction string
#  |
#  |  retrieve_tokenizer (base_model='T5')
#  |
#  |      returns and caches a tokenizer
#  |
#  |  retrieve_model(base_model='T5', training_dataset='amalgam')
#  |
#  |      returns and caches a model
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  predict(self, context, answer, base_model='T5', training_dataset='amalgam', num_beams=4, early_stopping=True, no_repeat_ngram_size=3, maximum_input_length=1024, maximum_target_length=50)
#  |
#  |  retrieve_model(self, base_model='T5', training_dataset='amalgam')
#  |
#  |  retrieve_tokenizer(self, base_model='T5')
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
p = Probe()

# %%
mary_had_a_little_lamb = "Mary had a little lamb, its fleece was white as snow. Everywhere the child went, the little lamb was sure to go."

# %%
panel(
    p,
    mary_had_a_little_lamb,
    ["Mary", "little", "white"],
    ["T5", "bart"],
    ["amalgam", "squad"],
)
# Out:
# Loading: RERobbins/qg_T5_amalgam from HuggingFace
# Loading: RERobbins/qg_T5_squad from HuggingFace
# Loading: RERobbins/qg_bart_amalgam from HuggingFace
# Loading: RERobbins/qg_bart_squad from HuggingFace
#    Base Model  Training Dataset  Answer  \
# 0          T5  Shuffled Blended    Mary
# 1          T5             SQuAD    Mary
# 2        BART  Shuffled Blended    Mary
# 3        BART             SQuAD    Mary
# 4          T5  Shuffled Blended  little
# 5          T5             SQuAD  little
# 6        BART  Shuffled Blended  little
# 7        BART             SQuAD  little
# 8          T5  Shuffled Blended   white
# 9          T5             SQuAD   white
# 10       BART  Shuffled Blended   white
# 11       BART             SQuAD   white
#
#                                        Prediction
# 0    who had a little lamb that was white as snow
# 1                          Who had a little lamb?
# 2              who had a little lamb in the bible
# 3                          Who had a little lamb?
# 4                what was the size of mary's lamb
# 5                      What size was Mary's lamb?
# 6        how many lamb did mary have in the bible
# 7                        How big was Mary's lamb?
# 8        what color was the fleece of mary's lamb
# 9            What color was Mary's lamb's fleece?
# 10       what color was the fleece of mary's lamb
# 11  What color was the fleece of the little lamb?

# %%
fossie_had_a_little_lamb = "Fossie had a little lamb, its fleece was white as snow. Everywhere the puppy went, the little lamb was sure to go."

# %%
df = panel(
    p,
    fossie_had_a_little_lamb,
    ["Fossie", "little", "white"],
    ["T5", "bart"],
    ["amalgam", "squad"],
)
df
# Out:
#    Base Model  Training Dataset  Answer  \
# 0          T5  Shuffled Blended  Fossie
# 1          T5             SQuAD  Fossie
# 2        BART  Shuffled Blended  Fossie
# 3        BART             SQuAD  Fossie
# 4          T5  Shuffled Blended  little
# 5          T5             SQuAD  little
# 6        BART  Shuffled Blended  little
# 7        BART             SQuAD  little
# 8          T5  Shuffled Blended   white
# 9          T5             SQuAD   white
# 10       BART  Shuffled Blended   white
# 11       BART             SQuAD   white
#
#                                     Prediction
# 0                who had a little lamb in snow
# 1                       Who had a little lamb?
# 2         what was the name of the little lamb
# 3                       Who had a little lamb?
# 4           what was the size of fossie's lamb
# 5          What was the size of Fossie's lamb?
# 6             how many lamb does a Fossie have
# 7                   How big was Fossie's lamb?
# 8   what color was the fleece of fossie's lamb
# 9       What color was Fossie's lamb's fleece?
# 10              what color was Fossie's fleece
# 11             What color was Fossie's fleece?

# %%
irving_had_a_little_lamb = "Irving had a little lamb, its fleece was white as snow. Everywhere the child went, the little lamb was sure to go."

# %%
df = panel(
    p,
    irving_had_a_little_lamb,
    ["Irving", "little", "white"],
    ["T5", "bart"],
    ["amalgam", "squad"],
)
df
# Out:
#    Base Model  Training Dataset  Answer  \
# 0          T5  Shuffled Blended  Irving
# 1          T5             SQuAD  Irving
# 2        BART  Shuffled Blended  Irving
# 3        BART             SQuAD  Irving
# 4          T5  Shuffled Blended  little
# 5          T5             SQuAD  little
# 6        BART  Shuffled Blended  little
# 7        BART             SQuAD  little
# 8          T5  Shuffled Blended   white
# 9          T5             SQuAD   white
# 10       BART  Shuffled Blended   white
# 11       BART             SQuAD   white
#
#                                       Prediction
# 0   who had a little lamb that was white as snow
# 1                         Who had a little lamb?
# 2          who was the father of the little lamb
# 3                         Who had a little lamb?
# 4                 What was Irving's lamb's size?
# 5                 What was Irving's lamb's size?
# 6    how many lamb did roberts have in the bible
# 7                     How big was Irving's lamb?
# 8                What color was Irving's fleece?
# 9         What color was Irving's lamb's fleece?
# 10         what color was the fleece of the lamb
# 11        What color was Irving's lamb's fleece?

# %%
irving_had_a_labradoodle = "Irving had a labradoodle named Fossie, its fur was white as snow. Everywhere that child went, the little dog was sure to go."

# %%
df = panel(
    p,
    irving_had_a_labradoodle,
    ["Irving", "Fossie", "little", "white", "labradoodle"],
    ["T5", "bart"],
    ["amalgam", "squad"],
)
df
# Out:
#    Base Model  Training Dataset       Answer  \
# 0          T5  Shuffled Blended       Irving
# 1          T5             SQuAD       Irving
# 2        BART  Shuffled Blended       Irving
# 3        BART             SQuAD       Irving
# 4          T5  Shuffled Blended       Fossie
# 5          T5             SQuAD       Fossie
# 6        BART  Shuffled Blended       Fossie
# 7        BART             SQuAD       Fossie
# 8          T5  Shuffled Blended       little
# 9          T5             SQuAD       little
# 10       BART  Shuffled Blended       little
# 11       BART             SQuAD       little
# 12         T5  Shuffled Blended        white
# 13         T5             SQuAD        white
# 14       BART  Shuffled Blended        white
# 15       BART             SQuAD        white
# 16         T5  Shuffled Blended  labradoodle
# 17         T5             SQuAD  labradoodle
# 18       BART  Shuffled Blended  labradoodle
# 19       BART             SQuAD  labradoodle
#
#                                        Prediction
# 0              who had a labradoodle named fossie
# 1             Who had a labradoodle named Fossie?
# 2                     who had a dog called Fossie
# 3                     Who had a dog named Fossie?
# 4               what was the name of irving's dog
# 5                  What was Irving's labradoodle?
# 6       what was the name of the dog in the movie
# 7            What was Irving's labradoodle named?
# 8                         What was Fossie's size?
# 9                         What was Fossie's size?
# 10  how old was the dog that went to the dog show
# 11                            How big was Fossie?
# 12                   What color was Fossie's fur?
# 13                   What color was Fossie's fur?
# 14                   What color was Fossie's fur?
# 15                   What color was Fossie's fur?
# 16               what kind of dog did irving have
# 17              What type of dog did Irving have?
# 18       what kind of dog was fossie in the movie
# 19             What breed of dog did Irving have?

# %%
goldilocks = """Once upon a time there were three bears who lived in a house in the forest. 
There was a great big father bear, a middle-sized mother bear and a tiny baby bear.
One morning, their breakfast porridge was too hot to eat, so they decided to go for a walk in the forest. 
While they were out, a little girl called Goldilocks came through the trees and found their house. 
She knocked on the door and, as there was no answer, she pushed it open and went inside.
In front of her was a table with three chairs, one large chair, one middle-sized chair and one small chair. 
On the table were three bowls of porridge, one large bowl, one middle-sized bowl and one small bowl – and three spoons.
Goldilocks was hungry and the porridge looked good, so she sat in the great big chair, picked up the large spoon and tried some of the porridge from the big bowl. 
But the chair was very big and very hard, the spoon was heavy and the porridge too hot.
Goldilocks jumped off quickly and went over to the middle-sized chair. 
But this chair was far too soft, and when she tried the porridge from the middle-sized bowl it was too cold. 
So she went over to the little chair and picked up the smallest spoon and tried some of the porridge from the tiny bowl.
This time it was neither too hot nor too cold. 
It was just right and so delicious that she ate it all up. 
But she was too heavy for the little chair and it broke in pieces under her weight.
Next Goldilocks went upstairs, where she found three beds. 
There was a great big bed, a middle-sized bed and a tiny little bed. 
By now she was feeling rather tired. 
So she climbed into the big bed and lay down. 
The big bed was very hard and far too big. 
Then she tried the middle-sized bed, but that was far too soft. 
So she climbed into the tiny little bed. 
It was neither too hard nor too soft. 
In fact, it felt just right, all cosy and warm. 
And in no time at all Goldilocks fell fast asleep.
In a little while, the three bears came back from their walk in the forest. 
They saw at once that someone had pushed open the door of their house and Father Bear looked around. 
Then roared with a growly voice.
Mother Bear said in a quiet gentle voice.
"Somebody has been sitting in my chair.
Then Little Bear said in small squeaky baby voice.
"Somebody has been sitting in my chair and has broken it!"
Then Father Bear looked at his bowl of porridge and saw the spoon in it and he said in his great big growly voice,
"SOMEBODY HAS BEEN EATING MY PORRIDGE"
Then Mother Bear saw that her bowl had a spoon in it, and said in her quiet voice.
"Somebody has been eating my porridge Little Bear looked at his porridge bowl and said in his small squeaky baby voice,
"Somebody has been eating my porridge, and has eaten it all up:-
Then the three bears went upstairs, and Father Bear saw at once that his bed was untidy, and he said in his great big growly voice,
"SOMEBODY HAS BEEN SLEEPING IN MY BED!"
Mother Bear saw that her bed, too, had the bedclothes turned back, and she said in her quiet gentle voice,
"Somebody has been sleeping in my bed!"
Then Little Bear looked at his bed and said in his small squeaky baby voice,
"Somebody is sleeping in my bed!"
He squeaked so loudly that Goldilocks woke up with a start. She jumped out of bed, and away she ran, down the stairs and out into the forest. And the three bears never saw her again."""

# %%
panel(
    p,
    goldilocks,
    ["the forest", "it broke", "it was too hot", "tiny"],
    ["T5", "bart"],
    ["amalgam", "squad"],
)
# Out:
#    Base Model  Training Dataset          Answer  \
# 0          T5  Shuffled Blended      the forest
# 1          T5             SQuAD      the forest
# 2        BART  Shuffled Blended      the forest
# 3        BART             SQuAD      the forest
# 4          T5  Shuffled Blended        it broke
# 5          T5             SQuAD        it broke
# 6        BART  Shuffled Blended        it broke
# 7        BART             SQuAD        it broke
# 8          T5  Shuffled Blended  it was too hot
# 9          T5             SQuAD  it was too hot
# 10       BART  Shuffled Blended  it was too hot
# 11       BART             SQuAD  it was too hot
# 12         T5  Shuffled Blended            tiny
# 13         T5             SQuAD            tiny
# 14       BART  Shuffled Blended            tiny
# 15       BART             SQuAD            tiny
#
#                                                            Prediction
# 0                                     Where did the three bears live?
# 1                            Where did the three bears go for a walk?
# 2                                          Where did Goldilocks live?
# 3                                     Where did the three bears live?
# 4                                  What happened to the little chair?
# 5                                  What happened to the little chair?
# 6                                  What happened to the little chair?
# 7                                  What happened to the little chair?
# 8                             What was the problem with the porridge?
# 9                             What was the problem with the porridge?
# 10                           Why did Goldilocks want to eat porridge?
# 11                    Why did Goldilocks go for a walk in the forest?
# 12                                What was the size of the baby bear?
# 13  What was the size of the little bed that Goldilocks climbed into?
# 14                             What was the size of Goldilocks's bed?
# 15                                        How big was the little bed?

# %%
big_game = """BERKELEY - Jackson Sirmon scored on a 37-yard return following a wild play with two fumbles and the Cal football team rallied from a double-digit deficit in the fourth quarter to beat Stanford 27-20 in the 125th edition of the Big Game on Saturday.
"It's really neat... as a defensive player, you don't get a lot of opportunities to score touchdowns and you have to enjoy them when you get them," said Sirmon, who played in his first Big Game on Saturday. "It was very neat especially considering the timing of it all.""
The Golden Bears (4-7, 2-6 Pac-12) trailed 17-6 in the fourth quarter when Jack Plummer started the comeback with a 1-yard touchdown pass to Monroe Young.
Then things really went crazy on the ensuing possession for Stanford (3-8, 1-8).
Backup quarterback Ashton Daniels took a direct snap and ran to his left. He was stripped of the ball by Daniel Scott and Cal's Jeremiah Earby recovered. But Daniels then knocked the ball loose from Earby for a second fumble on the play only to have Sirmon scoop it up and run in to give Cal a 20-17 lead with 9:54 to play.
"It bounced right to me,'' Sirmon said." I was in the right place at the right time. All I did that play is I didn't mess it up. The ball came right to me and I ran with it.
Stanford had three more drives to rally. But the Cardinal punted twice and Scott came up with an interception with just more than two minutes to play, setting up Jaydn Ott's 1-yard run that sealed the win in front of a sellout crowd of 51,892.
"We know how important this game is to us as a team, our administration and our support staff," Travers Family Head Football Coach Justin Wilcox said. "Our fans and students were just incredible tonight. What an awesome environment." """

# %%
pprint.pprint(big_game)
# Out:
# ('BERKELEY - Jackson Sirmon scored on a 37-yard return following a wild play '
#  'with two fumbles and the Cal football team rallied from a double-digit '
#  'deficit in the fourth quarter to beat Stanford 27-20 in the 125th edition of '
#  'the Big Game on Saturday.\n'
#  '"It\'s really neat... as a defensive player, you don\'t get a lot of '
#  'opportunities to score touchdowns and you have to enjoy them when you get '
#  'them," said Sirmon, who played in his first Big Game on Saturday. "It was '
#  'very neat especially considering the timing of it all.""\n'
#  'The Golden Bears (4-7, 2-6 Pac-12) trailed 17-6 in the fourth quarter when '
#  'Jack Plummer started the comeback with a 1-yard touchdown pass to Monroe '
#  'Young.\n'
#  'Then things really went crazy on the ensuing possession for Stanford (3-8, '
#  '1-8).\n'
#  'Backup quarterback Ashton Daniels took a direct snap and ran to his left. He '
#  "was stripped of the ball by Daniel Scott and Cal's Jeremiah Earby recovered. "
#  'But Daniels then knocked the ball loose from Earby for a second fumble on '
#  'the play only to have Sirmon scoop it up and run in to give Cal a 20-17 lead '
#  'with 9:54 to play.\n'
#  '"It bounced right to me,\'\' Sirmon said." I was in the right place at the '
#  "right time. All I did that play is I didn't mess it up. The ball came right "
#  'to me and I ran with it.\n'
#  'Stanford had three more drives to rally. But the Cardinal punted twice and '
#  'Scott came up with an interception with just more than two minutes to play, '
#  "setting up Jaydn Ott's 1-yard run that sealed the win in front of a sellout "
#  'crowd of 51,892.\n'
#  '"We know how important this game is to us as a team, our administration and '
#  'our support staff," Travers Family Head Football Coach Justin Wilcox said. '
#  '"Our fans and students were just incredible tonight. What an awesome '
#  'environment." ')

# %%
answers = [
    "Jakson Sirmon",
    "Stanford",
    "Jaydn Ott",
    "51,892",
    "17-6",
    "20-17",
    "27-20",
    "three-drives",
]
df = panel(p, big_game, answers, ["T5"], ["amalgam", "squad"])
df
# Out:
#    Base Model  Training Dataset         Answer  \
# 0          T5  Shuffled Blended  Jakson Sirmon
# 1          T5             SQuAD  Jakson Sirmon
# 2          T5  Shuffled Blended       Stanford
# 3          T5             SQuAD       Stanford
# 4          T5  Shuffled Blended      Jaydn Ott
# 5          T5             SQuAD      Jaydn Ott
# 6          T5  Shuffled Blended         51,892
# 7          T5             SQuAD         51,892
# 8          T5  Shuffled Blended           17-6
# 9          T5             SQuAD           17-6
# 10         T5  Shuffled Blended          20-17
# 11         T5             SQuAD          20-17
# 12         T5  Shuffled Blended          27-20
# 13         T5             SQuAD          27-20
# 14         T5  Shuffled Blended   three-drives
# 15         T5             SQuAD   three-drives
#
#                                                              Prediction
# 0                       Who scored on a 37-yard return in the Big Game?
# 1                                       Who scored on a 37-yard return?
# 2                                     Who did Cal beat in the Big Game?
# 3   Who did the Golden Bears beat in the 125th edition of the Big Game?
# 4         Who scored a 1-yard run in the final quarter of the Big Game?
# 5                        Who scored a 1-yard run in the fourth quarter?
# 6                                    How many people attended the game?
# 7                                    How many people attended the game?
# 8                  How many points did Cal trail in the fourth quarter?
# 9     How many points did the Golden Bears trail in the fourth quarter?
# 10                    What was the final score for Cal in the Big Game?
# 11                                What was the score with 9:54 to play?
# 12                 How many points did Cal score in the 125th Big Game?
# 13       What was the final score of the 125th edition of the Big Game?
# 14                          How many drives did Stanford have to rally?
# 15                          How many drives did Stanford have to rally?

# %%
models = p.models

# %%
for tag, model in models.items():
    print (tag, sum (param.numel() for param in model.parameters()))
# Out:
# ('T5', 'amalgam') 247577856
# ('T5', 'squad') 247577856
# ('bart', 'amalgam') 139420416
# ('bart', 'squad') 139420416

# %%
models.keys()
# Out:
# dict_keys([('T5', 'amalgam'), ('T5', 'squad'), ('bart', 'amalgam'), ('bart', 'squad')])
